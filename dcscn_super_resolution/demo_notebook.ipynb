# %% [markdown]
# #Enable GPU runtime.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd 'drive/My Drive/dcscn-super-resolution'
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1_axeL0Lp6pGBwNZvL2CfQWD9IpHyAJ9f/dcscn-super-resolution
# augmentation.py      Dockerfile   helper   Pipfile	 sr_video.py
# convert_y.py	     documents	  LICENSE  Pipfile.lock  test.py
# data		     evaluate.py  log.txt  __pycache__	 test_vid.mp4
# DCSCN.py	     frames.py	  models   README.md	 tf_log
# demo_notebook.ipynb  graphs	  output   sr.py	 train.py

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 96kB/s
# ...
# ERROR: umap-learn 0.4.2 has requirement scipy>=1.3.1, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %% [markdown]
# ### Training on your own dataset

# %% [markdown]
# Make a subfolder in the 'data' folder and add your images into this subfolder. Specify name of the subfolder with `--dataset` argument.
#
# Check `helper/args.py` for more training arguments to pass.

# %%
# !python train.py --dataset=name_of_dataset

# %%
# If name of subfolder is 'my_dataset'
# !python train.py --dataset=my_dataset

# %% [markdown]
# ### Super Resolution of Single Image

# %%
# default model
# !python sr.py --file=/path/to/your/image

# %%
# apply super resolution with small model
python sr.py --file=/path/to/your/image --layers=8 --filters=96

# %% [markdown]
# ### Super Resolution of Video

# %% [markdown]
# `--video_path` : Location of input video
#
# `--frame_out_dir` : Location where the frames are to be stored
#
# `--video_out_dir` : Location where the final compiled video has to be stored

# %%
# !python test.py --video_path /path/to/your/video --frame_out_dir /path/to/output/frames --video_out_dir /path/to/output/video

# %%
# Example :
# !python test.py --video_path test_vid.mp4 --frame_out_dir /content/frames --video_out_dir /content

# %% [markdown]
# # Check README.md for more detailed and complete instructions on setup and execution.
